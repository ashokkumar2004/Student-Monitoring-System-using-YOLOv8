# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 10.8 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to /tmp/pip-req-build-cm01y8z_
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git /tmp/pip-req-build-cm01y8z_
#   Resolved https://github.com/ultralytics/ultralytics.git to commit 70c400ee158fc52361e6d38e4b93f55fff21edd7
#   Preparing metadata (setup.py) ... done
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/Student monitoring system/images/frame0.jpg"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 78.4MB/s]
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Student monitoring system/images/frame0.jpg: 384x640 17 persons, 1 handbag, 1 bottle, 1 chair, 1 dining table, 1 laptop, 62.5ms
# Speed: 11.6ms preprocess, 62.5ms inference, 41.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="/content/drive/MyDrive/Student monitoring system/images/frame0.jpg"
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 79.4MB/s]
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Student monitoring system/images/frame0.jpg: 384x640 18 persons, 1 backpack, 1 dining table, 1 laptop, 107.8ms
# Speed: 3.1ms preprocess, 107.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

# Load a segmentation model
model = YOLO("yolov8n-seg.pt")

model.predict(source="/content/drive/MyDrive/Student monitoring system/images/frame0.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/Student monitoring system/images/frame0.jpg: 384x640 18 persons, 1 backpack, 1 dining table, 1 laptop, 217.4ms
# Speed: 12.1ms preprocess, 217.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/drive/MyDrive/Student monitoring system/images/frame0.jpg"
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 23.7MB/s]
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 14.7MB/s]
# image 1/1 /content/drive/MyDrive/Student monitoring system/images/frame0.jpg: 224x224 marimba 0.24, bobsled 0.16, cello 0.05, drum 0.04, stretcher 0.03, 4.0ms
# Speed: 7.8ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import IPython
from IPython.display import Image
Image(filename=f'/content/runs/detect/predict/frame0.jpg',width=800)

# %%
Image(filename=f'/content/runs/classify/predict/frame0.jpg',width=800)

# %%
Image(filename=f'/content/runs/segment/predict/frame0.jpg',width=800)

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
'''!unzip '/content/drive/MyDrive/student 1/Student Monitoring System.v3i.yolov8.zip' -d '/content/drive/MyDrive/student 1/exported dataset''''
# Out:
# Archive:  /content/drive/MyDrive/student 1/Student Monitoring System.v3i.yolov8.zip
# replace /content/drive/MyDrive/student 1/exported dataset/README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
results = model.train(data='/content/drive/MyDrive/student 1/exported dataset/data.yaml',epochs=25, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/epoch6/last.pt')
results = model.train(resume=True)
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import ultralytics
ultralytics.utils.metrics.ConfusionMatrix
# Out:
# ultralytics.utils.metrics.ConfusionMatrix

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
 # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/student 1/exported dataset/valid/labels.cache... 119 images, 0 backgrounds, 0 corrupt: 100%|██████████| 119/119 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:19<00:00,  2.41s/it]
#                    all        119       2338      0.623      0.698      0.708      0.302
#         High Attention        119        961       0.58      0.755      0.713      0.299
#          Low Attention        119       1377      0.666       0.64      0.703      0.305
# Speed: 0.9ms preprocess, 15.4ms inference, 0.0ms loss, 7.7ms postprocess per image
# Results saved to runs/detect/train32
# array([    0.29877,      0.3049])

# %%
metrics.box.maps
# Out:
# array([    0.29877,      0.3049])

# %%
import IPython
from IPython.display import Image

# %%
Image(filename=f'/content/runs/detect/train3/confusion_matrix.png',width=800)

# %%
Image(filename=f'/content/runs/detect/train3/results.png')

# %%
model.predict('/content/drive/MyDrive/student 1/exported dataset/valid/images/frame3915_jpg.rf.24c9383d9eea806ee108c6c21a5fede7.jpg',save=True,imgsz=320,conf=0.5)
# Out:
# image 1/1 /content/drive/MyDrive/student 1/exported dataset/valid/images/frame3915_jpg.rf.24c9383d9eea806ee108c6c21a5fede7.jpg: 192x320 1 High Attention, 7 Low Attentions, 100.3ms
# Speed: 1.1ms preprocess, 100.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/detect/train33
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'High Attention', 1: 'Low Attention'}
#  orig_img: array([[[129, 137, 136],
#          [124, 132, 131],
#          [120, 128, 127],
#          ...,
#          [140, 145, 144],
#          [140, 145, 144],
#          [140, 145, 144]],
#
#         [[126, 134, 133],
#          [123, 131, 130],
#          [120, 128, 127],
#          ...,
#          [141, 146, 145],
#          [140, 145, 144],
#          [140, 145, 144]],
#
#         [[122, 130, 129],
#          [122, 130, 129],
#          [120, 128, 127],
# ...

# %%
Image(filename=f'/content/runs/detect/train33/frame3915_jpg.rf.24c9383d9eea806ee108c6c21a5fede7.jpg')
